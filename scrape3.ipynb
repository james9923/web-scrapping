# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
data = requests.get('https://www.konga.com/category/air-conditioners-1011')

# %%
print(data)
# Out:
# <Response [200]>

# %%
result = bs(data.content, 'html.parser')

# %%
print(result.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="initial-scale=1, width=device-width" name="viewport"/>
#   <meta content="wtrnkQOcU_Pk78MKMyMrUwn6CA-Om0hc4eYXS03AVFM" name="google-site-verification"/>
#   <meta content="#ed017f" name="theme-color"/>
#   <meta content="#ed017f" name="msapplication-TileColor"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="#ed017f" name="msapplication-TileColor"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="Konga" name="application-name"/>
#   <link href="/static/android-chrome-192x192.png" rel="icon" sizes="192x192"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#ed017f" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Konga" name="apple-mobile-web-app-title"/>
# ...

# %%
price = result.find('span', class_="d7c0f_sJAqi")

# %%
print(price)
# Out:
# None

# %%
product = result.find_all('h3', class_="_25677_1VXsu")

# %%
print(product)
# Out:
# []

# %%
for x in product:
    print(x.text)

# %%
r = result.find_all('h3')
print(r)
# Out:
# [<h3>Email Support</h3>, <h3>Phone Support</h3>, <h3>Whatsapp</h3>, <h3>Get Latest Deals</h3>, <h3>App Store</h3>, <h3>Google Play</h3>]

# %%
data1 = requests.get('https://www.jumia.com.ng/air-conditioners-accessories/')

# %%
print(data1)
# Out:
# <Response [200]>

# %%
res = bs(data1.content, 'html.parser')

# %%
print(res.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Air Treatment Unit - Buy Online | Jumia Nigeria
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Nigeria" property="og:site_name"/>
#   <meta content="Air Treatment Unit - Buy Online | Jumia Nigeria" property="og:title"/>
#   <meta content="Discover air treatment unit online at Jumia Nigeria | Large selection of air purifiers &amp; more from top brands | Enjoy pay on delivery &amp; best prices | Order today! " property="og:description"/>
#   <meta content="/air-conditioners-accessories/" property="og:url"/>
#   <meta content="https://ng.jumia.is/cms/jumialogonew.png" property="og:image"/>
#   <meta content="en_NG" property="og:locale"/>
#   <meta content="Air Treatment Unit - Buy Online | Jumia Nigeria" name="title"/>
#   <meta content="index,follow" name="robots"/>
# ...

# %%
r1 = res.find_all('div', class_="prc")

# %%
print(r1)
# Out:
# [<div class="prc">₦ 6,860</div>, <div class="prc">₦ 155,650</div>, <div class="prc">₦ 3,999</div>, <div class="prc">₦ 7,990</div>, <div class="prc">₦ 155,000</div>, <div class="prc">₦ 164,115</div>, <div class="prc">₦ 3,999</div>, <div class="prc">₦ 9,500</div>, <div class="prc">₦ 7,100</div>, <div class="prc">₦ 51,000</div>, <div class="prc">₦ 12,599</div>, <div class="prc">₦ 12,500</div>, <div class="prc">₦ 13,500</div>, <div class="prc">₦ 62,000</div>, <div class="prc">₦ 8,400</div>, <div class="prc">₦ 9,500</div>, <div class="prc">₦ 9,000</div>, <div class="prc">₦ 8,640</div>, <div class="prc">₦ 152,949</div>, <div class="prc">₦ 61,900</div>, <div class="prc">₦ 9,500</div>, <div class="prc">₦ 166,900</div>, <div class="prc">₦ 61,299</div>, <div class="prc">₦ 157,999</div>, <div class="prc">₦ 130,000</div>, <div class="prc">₦ 228,000</div>, <div class="prc">₦ 8,000 - ₦ 10,500</div>, <div class="prc">₦ 3,990</div>, <div class="prc">₦ 157,999</div>, <div class="prc">₦ 55,000</div>, 
# ...

# %%
print(result.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="initial-scale=1, width=device-width" name="viewport"/>
#   <meta content="wtrnkQOcU_Pk78MKMyMrUwn6CA-Om0hc4eYXS03AVFM" name="google-site-verification"/>
#   <meta content="#ed017f" name="theme-color"/>
#   <meta content="#ed017f" name="msapplication-TileColor"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="#ed017f" name="msapplication-TileColor"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="Konga" name="application-name"/>
#   <link href="/static/android-chrome-192x192.png" rel="icon" sizes="192x192"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#ed017f" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Konga" name="apple-mobile-web-app-title"/>
# ...

# %%
s = result.find_all('span')

# %%
print(s)
# Out:
# [<span class="_0c0a6__yJ0d"></span>, <span class="f79e8_3c319">My Cart</span>, <span class="e8a0c_i6khK">0 items in cart</span>, <span class="f79e8_3c319">Track Orders</span>, <span class="e8a0c_i6khK">View order status</span>, <span class="f79e8_3c319">Sell on Konga</span>, <span class="e8a0c_i6khK">Join other merchants</span>, <span class="f79e8_3c319">Physical Stores</span>, <span class="e8a0c_i6khK">Stores around you</span>, <span>Categories</span>, <span class="_33353_3KdIO">Computers and Accessories</span>, <span class="_3b1e8_3gyVo"><svg aria-label="chevron-next-outline" class="" height="16" name="chevron-next-outline" viewbox="0 0 9 16" width="9" xmlns="http://www.w3.org/2000/svg"><path d="M.659.65a.532.532 0 0 0 0 .75l6.583 6.593-6.583 6.606a.532.532 0 0 0 0 .75.527.527 0 0 0 .747 0L8.349 8.38a.519.519 0 0 0 .155-.375.54.54 0 0 0-.155-.375L1.406.662A.516.516 0 0 0 .659.65z" fill="#50545B" fill-rule="evenodd"></path></svg></span>, <span class="_33353_3KdIO">Phones and Tablets
# ...

# %%
s2 = result.find('span', class_="f79e8_3c319")

# %%
print(s2)
# Out:
# <span class="f79e8_3c319">My Cart</span>

# %%
print(s2.text)
# Out:
# My Cart

# %%
header = result.find_all('h3')
print(header)
# Out:
# [<h3>Email Support</h3>, <h3>Phone Support</h3>, <h3>Whatsapp</h3>, <h3>Get Latest Deals</h3>, <h3>App Store</h3>, <h3>Google Play</h3>]

# %%
for i in header:
    print(i.text)
# Out:
# Email Support
# Phone Support
# Whatsapp
# Get Latest Deals
# App Store
# Google Play

# %%
fo = requests.get('https://www.fouanistore.com/hisense-product/hisense-appliances/hisense-air-conditioners/hisense-ac-split-1hp-clone-en/')

# %%
print(fo)
# Out:
# <Response [200]>

# %%
fou = bs(fo.content, 'html.parser')

# %%
hp = fou.find_all('span', class_="ty-price-num")

# %%
for m in hp:
    print(m.text)
# Out:
# ₦
# 159,000
# ₦
# 159,000
# ₦
# 144,900
# ₦
# 244,900
# ₦
# 222,800
# ₦
# 126,500
# ₦
# 77,000
# ₦
# 107,000
# ₦
# 155,000
# ₦
# 192,000
# ₦
# 142,500
# ₦
# 188,000
# ₦
# 64,900
# ₦
# 30,500
# ₦
# 139,500
# ₦
# 191,000

# %%
d5 = fou.find('span', id = "sec_discounted_price_770")

# %%
print(d5)
# Out:
# <span class="ty-price-num" id="sec_discounted_price_770">159,000</span>

# %%
print(d5.text)
# Out:
# 159,000

# %%
d51 = d5.text

# %%
print(d51)
# Out:
# 159,000

# %%
print(type(d51))
# Out:
# <class 'str'>

# %%
ji = requests.get('https://jiji.ng/home-appliances?query=1.5HP%20Hisense%20AC%20')

# %%
jiji = bs(ji.content, 'html.parser')

# %%
jiji1 = jiji.find('div', class_="qa-advert-price")

# %%
print(jiji1)
# Out:
# None

# %%
print(jiji.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="https://jiji.ng/home-appliances" rel="canonical"/>
#   <meta content="noindex, follow" name="robots"/>
#   <link href="//assets.jiji.ng" rel="preconnect"/>
#   <link href="//pictures-nigeria.jijistatic.com" rel="preconnect"/>
#   <title>
#    Home Appliances in Nigeria for sale ▷ Price on Jiji.ng
#   </title>
#   <meta content="Jiji.ng✓ More than 319  for sale ❤ Home Appliances starting from ➔ ₦ 80,000 in Nigeria ➔ choose and buy today! ❤" name="description"/>
#   <meta content="Jiji.ng✓ More than 319  for sale ❤ Home Appliances starting from ➔ ₦ 80,000 in Nigeria ➔ choose and buy today! ❤" name="abstract"/>
#   <meta content="Home Appliances, buy Home Appliances, Home Appliances in Nigeria, Home Appliances ads in Nigeria, sell Home Appliances in Nigeria" name="keywords"/>
#   <meta content="294481384086302" property="fb:app_id"/>
#   <meta content="932615913423241" property="fb:pages"/>
# ...

# %%
a1 = jiji.find("p", class_="b-list-advert__item-price")

# %%
print(a1)
# Out:
# <p class="b-list-advert__item-price">
# ₦ 155,000
# </p>

# %%
tcc = requests.get('http://diesel-refill.com.ng/iphone.html')

# %%
tccData = bs(tcc.content, 'html.parser')

# %%
print(tccData)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>iPhone - TCC Mall</title>
# <link href="css/style.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div class="container">
# <div class="header">
# <div class="logo">
# <h3><span><a href="index.html">TCC</a></span> Mall</h3>
# </div>
# <form>
# <input name="" placeholder="Search for Products and Brands" type="text"/>
# <input name="" type="submit" value="Search"/>
# </form>
# <div class="nav">
# <a href="">Login</a>
# <a href="">Sign Up</a>
# </div>
# </div>
# <div class="mini">
# <div class="mini1">
# <ul>
# <li><a href="samsung.html">Samsung</a></li>
# <li><a href="iphone.html">iPhone</a></li>
# <li><a href="vivo.html">Vivo</a></li>
# <li><a href="sony.html">Sony</a></li>
# <li><a href="tecno.html">Tecno</a></li>
# <li><a href="infinix.html">Infinix</a></li>
# <li><a href="oppo.html">Oppo</a></li>
# </ul>
# </div>
# <div class="mini2"></div>
# </div>
# <div class="main">
# <ul>
# <li class="product">
# ...

# %%
products = tccData.find_all('li', class_="product")

# %%
print(products)
# Out:
# [<li class="product">
# <div class="image"><img src="images/iphone/iphone1.jpg"/></div>
# <h3 class="pname">iPhone 13 Pro Max</h3>
# <p>Price: <span class="price">N900,000</span></p>
# <span class="call-to-action">Add to Cart</span>
# </li>, <li class="product">
# <div class="image"><img src="images/iphone/iphone2.jpg"/></div>
# <h3 class="pname">iPhone 11 Pro Max</h3>
# <p>Price: <span class="price">N370,000</span></p>
# <span class="call-to-action">Add to Cart</span>
# </li>, <li class="product">
# <div class="image"><img src="images/iphone/iphone3.jpg"/></div>
# <h3 class="pname">iPhone 11 Pro</h3>
# <p>Price: <span class="price">N320,000</span></p>
# <span class="call-to-action">Add to Cart</span>
# </li>, <li class="product">
# <div class="image"><img src="images/iphone/iphone4.jpg"/></div>
# <h3 class="pname">iPhone XS Max</h3>
# <p>Price: <span class="price">N270,000</span></p>
# <span class="call-to-action">Add to Cart</span>
# </li>, <li class="product">
# ...

# %%
for x in products:
    product_name = x.h3.text
    product_price = x.span.text
    
    print(product_name + ' - ' + product_price)
# Out:
# iPhone 13 Pro Max - N900,000
# iPhone 11 Pro Max - N370,000
# iPhone 11 Pro - N320,000
# iPhone XS Max - N270,000
# iPhone 13 - N695,000
# iPhone 7+ - N125,000
# iPhone 7 - N85,000
# iPhone X - N190,000
